# %%
import pandas as pd

# %%
df = pd.read_csv('cfs_2012_pumf_csv.txt', index_col=0)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head()
# Out:
#            ORIG_STATE  ORIG_MA ORIG_CFS_AREA  DEST_STATE  DEST_MA  \
# SHIPMT_ID
# 1                  25      148        25-148          25      148
# 2                  42      428        42-428           6    41740
# 3                  26      220        26-220          47      314
# 4                  20      556        20-556          20      556
# 5                  12    99999      12-99999          12    99999
#
#           DEST_CFS_AREA  NAICS  QUARTER SCTG  MODE  SHIPMT_VALUE  SHIPMT_WGHT  \
# SHIPMT_ID
# 1                25-148    333        2   35    14          2178           11
# 2              06-41740    311        3   35    14           344           11
# 3                47-314    322        2   27     4          4197         5134
# 4                20-556    323        1   29     4           116            6
# 5              12-99999   4235        3   33     5           388          527
#
#            SHIPMT_DIST_GC  SHIPMT_DIST_ROUTED TEMP_CNTL_YN EXPORT_YN  \
# ...
